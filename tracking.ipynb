# %%
 import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import threading
import json
import time
import os

# Load the YOLO model
model = YOLO("yolo11n.pt").to('gpu')

# Initialize DeepSORT tracker with stricter parameters
tracker = DeepSort(
    max_age=50,               
    n_init=5,                 
    max_cosine_distance=0.2,  
    nn_budget=100,            
    nms_max_overlap=0.5        
)

# RTSP Camera Address
rtsp_url = "rtsp://..."

# Asynchronous Video Stream Class
class VideoStream:
    def __init__(self, src=0):
        self.capture = cv2.VideoCapture(src)
        self.capture.set(cv2.CAP_PROP_BUFFERSIZE, 1)
        self.ret, self.frame = self.capture.read()
        self.stopped = False
        threading.Thread(target=self.update, args=()).start()

    def update(self):
        while not self.stopped:
            self.ret, self.frame = self.capture.read()

    def read(self):
        return self.ret, self.frame

    def stop(self):
        self.stopped = True

# JSON Logging Setup
json_file = "detections_with_ids.json"
if not os.path.exists(json_file):
    with open(json_file, 'w') as f:
        json.dump([], f)

# Append detections to JSON
def append_detection_to_json(detection):
    with open(json_file, 'r+') as file:
        try:
            data = json.load(file)
        except json.JSONDecodeError:
            data = []

        data.append(detection)
        file.seek(0)
        json.dump(data, file, indent=4)
        file.truncate()

# Start the Video Stream
stream = VideoStream(rtsp_url)

while True:
    ret, frame = stream.read()
    if not ret:
        break

    # Resize for faster processing
    frame = cv2.resize(frame, (640, 480))

    # Perform detection
    results = model(frame)

    detections = []
    for result in results[0].boxes.data.cpu().numpy():
        x1, y1, x2, y2, conf, cls = result

        # Only process detections with higher confidence and for the 'person' class
        if int(cls) == 0 and conf > 0.5:
            width, height = x2 - x1, y2 - y1
            detections.append(([x1, y1, width, height], conf))

    # Update DeepSORT tracker with detections
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        # Append detection to JSON
        detection = {
            "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
            "id": track_id,
            "class": "person",
            "confidence": float(conf),
            "bbox": [x1, y1, x2, y2]
        }
        append_detection_to_json(detection)

        # Annotate detection on the frame
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f'ID: {track_id}', (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow('Real-Time Human Tracking ', frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
stream.stop()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 from ultralytics import YOLO
#       3 from deep_sort_realtime.deepsort_tracker import DeepSort
#       4 import threading
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\__init__.py:11
#       8 if not os.environ.get("OMP_NUM_THREADS"):
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\models\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .fastsam import FastSAM
#       4 from .nas import NAS
#       5 from .rtdetr import RTDETR
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\models\fastsam\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .model import FastSAM
#       4 from .predict import FastSAMPredictor
#       5 from .val import FastSAMValidator
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\models\fastsam\model.py:5
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
#       3 from pathlib import Path
# ----> 5 from ultralytics.engine.model import Model
#       7 from .predict import FastSAMPredictor
#       8 from .val import FastSAMValidator
#
# File ~\AppData\Roaming\Python\Python39\site-packages\ultralytics\engine\model.py:8
#       5 from typing import Any, Dict, List, Union
#       7 import numpy as np
# ----> 8 import torch
#       9 from PIL import Image
#      11 from ultralytics.cfg import TASK2DATA, get_cfg, get_save_dir
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\__init__.py:2604
#    2600 from torch.func import vmap as vmap
#    2603 if not TYPE_CHECKING:
# -> 2604     from torch import _meta_registrations
#    2606 # Enable CUDA Sanitizer
#    2607 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_meta_registrations.py:11
#       9 import torch._prims_common as utils
#      10 from torch import SymBool, SymFloat, Tensor
# ---> 11 from torch._decomp import (
#      12     _add_op_to_registry,
#      13     _convert_out_params,
#      14     global_decomposition_table,
#      15     meta_table,
#      16 )
#      17 from torch._ops import OpOverload
#      18 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_decomp\__init__.py:284
#     280             decompositions.pop(op, None)
#     283 # populate the table
# --> 284 import torch._decomp.decompositions
#     285 import torch._refs
#     288 def core_aten_decompositions() -> "CustomDecompTable":
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_decomp\decompositions.py:15
#      13 import torch
#      14 import torch._meta_registrations
# ---> 15 import torch._prims as prims
#      16 import torch._prims_common as utils
#      17 import torch.nn.functional as F
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_prims\__init__.py:865
#     847 real = _make_prim(
#     848     schema="real(Tensor(a) self) -> Tensor(a)",
#     849     meta=partial(
#    (...)
#     855     doc="",
#     856 )
#     858 reciprocal = _make_elementwise_unary_prim(
#     859     "reciprocal",
#     860     impl_aten=torch.reciprocal,
#     861     doc="",
#     862     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     863 )
# --> 865 ndtri = _make_elementwise_unary_prim(
#     866     "ndtri",
#     867     impl_aten=torch.special.ndtri,
#     868     doc="",
#     869     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     870 )
#     872 neg = _make_elementwise_unary_prim(
#     873     "neg",
#     874     impl_aten=torch.neg,
#     875     doc="",
#     876     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     877 )
#     879 round = _make_elementwise_unary_prim(
#     880     "round",
#     881     impl_aten=torch.round,
#     882     doc="",
#     883     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     884 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_prims\__init__.py:492, in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     485 def _make_elementwise_unary_prim(
#     486     name: str, *, type_promotion: ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND, **kwargs
#     487 ):
#     488     """
#     489     Creates an elementwise unary prim.
#     490     """
# --> 492     return _make_prim(
#     493         schema=f"{name}(Tensor self) -> Tensor",
#     494         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#     495         return_type=RETURN_TYPE.NEW,
#     496         **kwargs,
#     497     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_prims\__init__.py:320, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api, register_conj_neg_fallthrough)
#     314 else:
#     315     mutates_args = [
#     316         arg.name
#     317         for arg in cpp_schema.arguments
#     318         if arg.alias_info is not None and arg.alias_info.is_write
#     319     ]
# --> 320     prim_def = torch.library.custom_op(
#     321         "prims::" + name,
#     322         _prim_impl,
#     323         mutates_args=tuple(mutates_args),
#     324         schema=schema,
#     325     )
#     326     prim_def.register_fake(meta)
#     328     # all view ops get conj/neg fallthroughs
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_library\custom_ops.py:145, in custom_op(name, fn, mutates_args, device_types, schema)
#     143 if fn is None:
#     144     return inner
# --> 145 return inner(fn)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_library\custom_ops.py:126, in custom_op.<locals>.inner(fn)
#     123     schema_str = schema
#     125 namespace, opname = name.split("::")
# --> 126 result = CustomOpDef(namespace, opname, schema_str, fn)
#     127 if schema is not None:
#     128     # Check that schema's alias annotations match those of `mutates_args`.
#     129     expected = set()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_library\custom_ops.py:173, in CustomOpDef.__init__(self, namespace, name, schema, fn)
#     170 self._torch_dispatch_fns: Dict[type, Callable] = {}
#     171 self._vmap_fn: Optional[Callable] = None
# --> 173 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
#     174 self._register_to_dispatcher()
#     175 self._disabled_kernel: Set = set()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\_library\custom_ops.py:786, in get_library_allowing_overwrite(namespace, name)
#     783     OPDEF_TO_LIB[qualname]._destroy()
#     784     del OPDEF_TO_LIB[qualname]
# --> 786 lib = torch.library.Library(namespace, "FRAGMENT")  # noqa: TOR901
#     787 OPDEF_TO_LIB[qualname] = lib
#     788 return lib
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\library.py:91, in Library.__init__(self, ns, kind, dispatch_key)
#      88     _library.utils.warn_deploy()
#      89     return
# ---> 91 frame = traceback.extract_stack(limit=3)[0]
#      92 filename, lineno = frame.filename, frame.lineno
#      93 self.m: Optional[Any] = torch._C._dispatch_library(
#      94     kind, ns, dispatch_key, filename, lineno
#      95 )
#
# File C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\lib\traceback.py:211, in extract_stack(f, limit)
#     209 if f is None:
#     210     f = sys._getframe().f_back
# --> 211 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212 stack.reverse()
#     213 return stack
#
# File C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\lib\traceback.py:362, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     359     result.append(FrameSummary(
#     360         filename, lineno, name, lookup_line=False, locals=f_locals))
#     361 for filename in fnames:
# --> 362     linecache.checkcache(filename)
#     363 # If immediate lookup was desired, trigger lookups now.
#     364 if lookup_lines:
#
# File C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python39_64\lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:
