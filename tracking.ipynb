# %%
 import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import threading
import json
import time
import os

# Load the YOLO model
model = YOLO("yolo11n.pt").to('cpu')

# Initialize DeepSORT tracker with stricter parameters
tracker = DeepSort(
    max_age=50,               # Increase track retention
    n_init=5,                 # More confirmations before creating a new ID
    max_cosine_distance=0.2,  # Stricter similarity threshold
    nn_budget=100,            # Size of the appearance feature cache
    nms_max_overlap=0.5       # Reduce overlapping detection issues
)

# RTSP Camera Address
rtsp_url = ""

# Asynchronous Video Stream Class
class VideoStream:
    def __init__(self, src=0):
        self.capture = cv2.VideoCapture(src)
        self.capture.set(cv2.CAP_PROP_BUFFERSIZE, 1)
        self.ret, self.frame = self.capture.read()
        self.stopped = False
        threading.Thread(target=self.update, args=()).start()

    def update(self):
        while not self.stopped:
            self.ret, self.frame = self.capture.read()

    def read(self):
        return self.ret, self.frame

    def stop(self):
        self.stopped = True

# JSON Logging Setup
json_file = "detections_with_ids.json"
if not os.path.exists(json_file):
    with open(json_file, 'w') as f:
        json.dump([], f)

# Append detections to JSON
def append_detection_to_json(detection):
    with open(json_file, 'r+') as file:
        try:
            data = json.load(file)
        except json.JSONDecodeError:
            data = []

        data.append(detection)
        file.seek(0)
        json.dump(data, file, indent=4)
        file.truncate()

# Start the Video Stream
stream = VideoStream(rtsp_url)

while True:
    ret, frame = stream.read()
    if not ret:
        break

    # Resize for faster processing
    frame = cv2.resize(frame, (1280, 720))

    # Perform detection
    results = model(frame)

    detections = []
    for result in results[0].boxes.data.cpu().numpy():
        x1, y1, x2, y2, conf, cls = result

        # Only process detections with higher confidence and for the 'person' class
        if int(cls) == 0 and conf > 0.5:
            width, height = x2 - x1, y2 - y1
            detections.append(([x1, y1, width, height], conf))

    # Update DeepSORT tracker with detections
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        # Append detection to JSON
        detection = {
            "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
            "id": track_id,
            "class": "person",
            "confidence": float(conf),
            "bbox": [x1, y1, x2, y2]
        }
        append_detection_to_json(detection)

        # Annotate detection on the frame
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f'ID: {track_id}', (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow('Real-Time Human Tracking with Consistent IDs', frame)

    # Exit on pressing 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
stream.stop()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 chair, 565.1ms
# Speed: 9.0ms preprocess, 565.1ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 624.1ms
# Speed: 10.1ms preprocess, 624.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 460.2ms
# Speed: 7.5ms preprocess, 460.2ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 1 chair, 595.6ms
# Speed: 10.1ms preprocess, 595.6ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 1 chair, 517.2ms
# Speed: 10.7ms preprocess, 517.2ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 1 chair, 513.5ms
# Speed: 10.9ms preprocess, 513.5ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 539.7ms
# Speed: 11.2ms preprocess, 539.7ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 531.0ms
# Speed: 8.7ms preprocess, 531.0ms inference, 14.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 578.4ms
# Speed: 10.1ms preprocess, 578.4ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 711.4ms
# Speed: 8.7ms preprocess, 711.4ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 685.4ms
# Speed: 14.7ms preprocess, 685.4ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 648.4ms
# Speed: 12.5ms preprocess, 648.4ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 689.8ms
# Speed: 10.6ms preprocess, 689.8ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 489.8ms
# Speed: 9.6ms preprocess, 489.8ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 516.8ms
# Speed: 8.2ms preprocess, 516.8ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 750.0ms
# Speed: 9.4ms preprocess, 750.0ms inference, 12.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 864.6ms
# Speed: 13.1ms preprocess, 864.6ms inference, 11.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 776.1ms
# Speed: 8.0ms preprocess, 776.1ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 574.2ms
# Speed: 8.1ms preprocess, 574.2ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 597.4ms
# Speed: 12.5ms preprocess, 597.4ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 499.6ms
# Speed: 11.0ms preprocess, 499.6ms inference, 15.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 517.7ms
# Speed: 10.6ms preprocess, 517.7ms inference, 14.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 541.8ms
# Speed: 12.1ms preprocess, 541.8ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 533.3ms
# Speed: 8.1ms preprocess, 533.3ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 516.8ms
# Speed: 7.7ms preprocess, 516.8ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 528.3ms
# Speed: 9.3ms preprocess, 528.3ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 431.6ms
# Speed: 8.1ms preprocess, 431.6ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 437.6ms
# Speed: 8.0ms preprocess, 437.6ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 456.4ms
# Speed: 9.2ms preprocess, 456.4ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 502.9ms
# Speed: 7.0ms preprocess, 502.9ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 510.6ms
# Speed: 7.6ms preprocess, 510.6ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 424.2ms
# Speed: 8.0ms preprocess, 424.2ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 434.4ms
# Speed: 7.6ms preprocess, 434.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 487.8ms
# Speed: 7.7ms preprocess, 487.8ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 461.8ms
# Speed: 10.7ms preprocess, 461.8ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 459.5ms
# Speed: 10.0ms preprocess, 459.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 469.4ms
# Speed: 8.7ms preprocess, 469.4ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 480.0ms
# Speed: 7.6ms preprocess, 480.0ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 530.5ms
# Speed: 7.6ms preprocess, 530.5ms inference, 12.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 469.6ms
# Speed: 10.6ms preprocess, 469.6ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 440.0ms
# Speed: 8.7ms preprocess, 440.0ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 511.4ms
# Speed: 9.2ms preprocess, 511.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 488.7ms
# Speed: 8.5ms preprocess, 488.7ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 465.9ms
# Speed: 9.4ms preprocess, 465.9ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 419.1ms
# Speed: 9.0ms preprocess, 419.1ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 474.2ms
# Speed: 8.4ms preprocess, 474.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 471.1ms
# Speed: 10.0ms preprocess, 471.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 470.5ms
# Speed: 10.7ms preprocess, 470.5ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 426.7ms
# Speed: 12.7ms preprocess, 426.7ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 497.2ms
# Speed: 7.0ms preprocess, 497.2ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 571.8ms
# Speed: 9.2ms preprocess, 571.8ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 589.7ms
# Speed: 9.5ms preprocess, 589.7ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 532.2ms
# Speed: 7.7ms preprocess, 532.2ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 571.9ms
# Speed: 8.6ms preprocess, 571.9ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 530.3ms
# Speed: 7.4ms preprocess, 530.3ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 459.1ms
# Speed: 7.1ms preprocess, 459.1ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 825.3ms
# Speed: 9.7ms preprocess, 825.3ms inference, 12.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1012.2ms
# Speed: 9.3ms preprocess, 1012.2ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 tv, 490.1ms
# Speed: 6.4ms preprocess, 490.1ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 tv, 459.3ms
# Speed: 7.9ms preprocess, 459.3ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 tv, 483.6ms
# Speed: 9.5ms preprocess, 483.6ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 578.4ms
# Speed: 7.0ms preprocess, 578.4ms inference, 10.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 427.2ms
# Speed: 10.5ms preprocess, 427.2ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 463.9ms
# Speed: 6.4ms preprocess, 463.9ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 690.7ms
# Speed: 8.1ms preprocess, 690.7ms inference, 19.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 891.7ms
# Speed: 8.2ms preprocess, 891.7ms inference, 14.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 712.7ms
# Speed: 7.6ms preprocess, 712.7ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 548.2ms
# Speed: 6.9ms preprocess, 548.2ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 446.6ms
# Speed: 10.1ms preprocess, 446.6ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 602.7ms
# Speed: 9.6ms preprocess, 602.7ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 571.7ms
# Speed: 8.5ms preprocess, 571.7ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 549.3ms
# Speed: 6.2ms preprocess, 549.3ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 487.2ms
# Speed: 8.1ms preprocess, 487.2ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 tv, 510.4ms
# Speed: 8.1ms preprocess, 510.4ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 424.0ms
# Speed: 6.9ms preprocess, 424.0ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 handbag, 2 chairs, 1 tv, 472.1ms
# Speed: 7.0ms preprocess, 472.1ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 backpack, 1 chair, 1 tv, 498.7ms
# Speed: 7.5ms preprocess, 498.7ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 suitcase, 2 chairs, 1 tv, 504.7ms
# Speed: 7.3ms preprocess, 504.7ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 tv, 470.6ms
# Speed: 9.0ms preprocess, 470.6ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 432.1ms
# Speed: 6.7ms preprocess, 432.1ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
